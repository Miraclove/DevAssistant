# %%
from utils import *
file_path = '/home/uework/AiWeb/pwz/github/data/md/api-doc/06.玩家.md'
json_output = md_to_json(file_path)
print(json.dumps(json_output, indent=4, ensure_ascii=False))
# Out:
# {
#     "events": [
#         {
#             "description": "是否是玩家",
#             "function_name": "is_player",
#             "args": [
#                 {
#                     "name": "obj",
#                     "type": "userdata",
#                     "comment": "对象"
#                 }
#             ],
#             "return": {
#                 "type": "boolean",
#                 "comment": "是否是玩家"
#             },
#             "example": "function isc_test_player:is_player()\n    local obj = module.player:getOwner()\n    local bRet = edi.player:is_player(obj)\n    RET_BOOL(bRet, \"edi.player:is_player\")\nend"
#         },
#         {
#             "description": "判断玩家是否死亡",
#             "function_name": "is_dead",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "boolean",
#                 "comment": "是否死亡"
#             },
#             "example": null
#         },
#         {
#             "description": "获取所有在线玩家",
#             "function_name": "get_all_players",
#             "args": [],
#             "return": {
#                 "type": "table",
#                 "comment": "玩家列表"
#             },
#             "example": "function isc_test_player:get_all_players()\n    local players = edi.player:get_all_players()\n    for _, player in pairs(players) do\n        LOGI(\"isc player test:\" .. edi.player:get_name(player))\n    end\nend"
#         },
#         {
#             "description": "通过名字获得玩家实例",
#             "function_name": "get_by_name",
#             "args": [
#                 {
#                     "name": "name",
#                     "type": "string",
#                     "comment": "玩家名字"
#                 }
#             ],
#             "return": {
#                 "type": "userdata",
#                 "comment": "玩家对象"
#             },
#             "example": null
#         },
#         {
#             "description": "通过唯一id获得玩家实例",
#             "function_name": "get_by_uuid",
#             "args": [
#                 {
#                     "name": "uuid",
#                     "type": "number",
#                     "comment": "玩家唯一id"
#                 }
#             ],
#             "return": {
#                 "type": "userdata",
#                 "comment": "玩家对象"
#             },
#             "example": null
#         },
#         {
#             "description": "获得玩家名字",
#             "function_name": "get_name",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "string",
#                 "comment": "玩家名字"
#             },
#             "example": "function isc_test_player:get_name()\n    local player = module.player\n    local name = edi.player:get_name(player)\n    LOGI(\"isc player test:\".. name)\nend"
#         },
#         {
#             "description": "获得玩家等级",
#             "function_name": "get_level",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "number",
#                 "comment": "玩家等级"
#             },
#             "example": "function isc_test_player:get_level()\n    local player = module.player\n    local level = edi.player:get_level(player)\n    LOGI(\"isc player test:\".. level)\nend"
#         },
#         {
#             "description": "获得玩家转生等级",
#             "function_name": "get_rlevel",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "number",
#                 "comment": "转生等级"
#             },
#             "example": "function isc_test_player:get_rlevel()\n    local player = module.player\n    local rlevel = edi.player:get_rlevel(player)\n    LOGI(\"isc player test:\".. rlevel)\nend"
#         },
#         {
#             "description": "添加玩家当前经验",
#             "function_name": "add_exp",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "exp_num",
#                     "type": "number",
#                     "comment": "经验值"
#                 }
#             ],
#             "example": null
#         },
#         {
#             "description": "减少玩家当前经验",
#             "function_name": "sub_exp",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "number",
#                 "comment": "玩家当前经验"
#             },
#             "example": null
#         },
#         {
#             "description": "获得玩家当前经验",
#             "function_name": "get_exp",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "exp_num",
#                     "type": "number",
#                     "comment": "经验值"
#                 }
#             ],
#             "example": null
#         },
#         {
#             "description": "获得玩家下一等级经验",
#             "function_name": "get_nexp",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "number",
#                 "comment": "玩家下一等级经验"
#             },
#             "example": null
#         },
#         {
#             "description": "获得玩家性别",
#             "function_name": "get_sex",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "number",
#                 "comment": "性别"
#             },
#             "example": "function isc_test_player:get_sex()\n    local player = module.player\n    local sex = edi.player:get_sex(player)\n    LOGI(\"isc player test:\".. sex)\nend"
#         },
#         {
#             "description": "获得玩家职业",
#             "function_name": "get_job",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "number",
#                 "comment": "职业"
#             },
#             "example": "function isc_test_player:get_job()\n    local player = module.player\n    local job = edi.player:get_job(player)\n    LOGI(\"isc player test:\".. job)\nend"
#         },
#         {
#             "description": "获得玩家uuid",
#             "function_name": "get_uuid",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "number",
#                 "comment": "uuid"
#             },
#             "example": "function isc_test_player:get_uuid()\n    local player = module.player\n    local uid = edi.player:get_uuid(player)\n    LOGI(\"isc player test:\".. uid)\nend"
#         },
#         {
#             "description": "获得玩家公会id",
#             "function_name": "get_guild_id",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "number",
#                 "comment": "公会id"
#             },
#             "example": "function isc_test_player:get_guild_id()\n    local player = module.player\n    local guild_id = edi.player:get_guild_id(player)\n    LOGI(\"isc player test:\".. guild_id)\nend"
#         },
#         {
#             "description": "获得货币数量",
#             "function_name": "get_money",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "item_id",
#                     "type": "number",
#                     "comment": "货币配置id"
#                 }
#             ],
#             "return": {
#                 "type": "number",
#                 "comment": "货币数量"
#             },
#             "example": "function isc_test_player:get_money()\n    local player = module.player\n    local item_id = 1\n    local money = edi.player:get_money(player, item_id)\n    LOGI(\"isc player test:\".. money)\nend"
#         },
#         {
#             "description": "获得对象当前坐标",
#             "function_name": "get_scene_pos",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "pos_info",
#                 "comment": "坐标"
#             },
#             "example": null
#         },
#         {
#             "description": "获得对象当前场景对象",
#             "function_name": "get_scene",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "userdata",
#                 "comment": "当前场景对象"
#             },
#             "example": "function isc_test_player:get_scene()\n    local player = module.player\n    local pScene = edi.player:get_scene(player)\n    local vecAllMonsters = edi.scene:get_all_monsters(pScene)\n    local monsterNum = #vecAllMonsters\n    print(\"--------------------------monsterNum:\"..monsterNum)\n    local scene_uuid = edi.scene:get_uuid(pScene)\n    LOGI(\"isc player test:\".. scene_uuid)\nend"
#         },
#         {
#             "description": "获得对象当前行会名称",
#             "function_name": "get_guild_name",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "string",
#                 "comment": "行会名称"
#             },
#             "example": "function isc_test_player:get_guild_name()\n    local player = module.player\n    local guild_name = edi.player:get_guild_name(player)\n    LOGI(\"isc player test:\".. guild_name)\nend"
#         },
#         {
#             "description": "获得攻击模式",
#             "function_name": "get_attack_mode",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "number",
#                 "comment": "攻击模式:0全体，1和平，2编组，3行会，4善恶，5阵营，6盟友，7敌"
#             },
#             "example": "function isc_test_player:get_attack_mode()\n    local player = module.player\n    local attack_mode = edi.player:get_attack_mode(player)\n    LOGI(\"isc player test:\".. attack_mode)\nend"
#         },
#         {
#             "description": "获得玩家状态",
#             "function_name": "get_state",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "eRoleState",
#                 "comment": "玩家状态(枚举在constDef.lua)"
#             },
#             "example": "function isc_test_player:get_state()\n    local player = module.player\n    local state = edi.player:get_state(player)\n    LOGI(\"isc player test:\".. state)\nend"
#         },
#         {
#             "description": "获取上一次登录时间 (秒)",
#             "function_name": "get_last_login_time",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "number",
#                 "comment": "上一次登录时间"
#             },
#             "example": "function isc_test_player:get_last_login_time()\n    local player = module.player\n    local time = edi.player:get_last_login_time(player)\n    LOGI(\"isc player test:\".. time)\nend"
#         },
#         {
#             "description": "获得上一个场景id",
#             "function_name": "get_last_map_id",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "number",
#                 "comment": "场景id"
#             },
#             "example": "function isc_test_player:get_last_map_id()\n    local player = module.player\n    local map_id = edi.player:get_last_map_id(player)\n    LOGI(\"isc player test:\".. map_id)\nend"
#         },
#         {
#             "description": "获得当前副本对象",
#             "function_name": "get_dg",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "userdata",
#                 "comment": "副本对象"
#             },
#             "example": "function isc_test_player:get_dg()\n    local player = module.player\n    local dg = edi.player:get_dg(player)\n    if dg then\n        local dg_uuid = edi.dg:get_uuid(dg)\n        LOGI(\"isc player test:\".. dg_uuid)\n    end\nend"
#         },
#         {
#             "description": "获得当前任务对象",
#             "function_name": "get_task",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "userdata",
#                 "comment": "任务对象"
#             },
#             "example": null
#         },
#         {
#             "description": "设置玩家状态",
#             "function_name": "set_state",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "state",
#                     "type": "eRoleState",
#                     "comment": "状态((枚举在constDef.lua))"
#                 }
#             ],
#             "example": "function isc_test_player:set_state()\n    local player = module.player\n    local state = ConstDef.eRoleState.play --待进入场景\n    edi.player:set_state(player, state)\n    local curr_state = edi.player:get_state(player)\n    LOGI(\"isc player test:\".. curr_state)\nend"
#         },
#         {
#             "description": "设置攻击模式",
#             "function_name": "set_attack_mode",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "mode",
#                     "type": "number",
#                     "comment": "攻击模式：0全体，1和平，2编组，3行会，4善恶，5阵营，6盟友，7敌"
#                 },
#                 {
#                     "name": "force",
#                     "type": "boolean",
#                     "comment": "是否强制"
#                 }
#             ],
#             "example": "function isc_test_player:set_attack_mode()\n    local player = module.player\n    local attack_mode = 5 --阵营模式\n    local force = true\n    edi.player:set_attack_mode(player, attack_mode, force)\n    local curr_mode = edi.player:get_attack_mode(player)\n    LOGI(\"isc player test:\".. curr_mode)\nend"
#         },
#         {
#             "description": "添加货币",
#             "function_name": "add_money",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "item_id",
#                     "type": "number",
#                     "comment": "货币配置id"
#                 },
#                 {
#                     "name": "count",
#                     "type": "number",
#                     "comment": "货币数量"
#                 }
#             ],
#             "return": {
#                 "type": "boolean",
#                 "comment": "是否添加成功"
#             },
#             "example": "function isc_test_player:add_money()\n    local player = module.player\n    local item_id = 1\n    local before_money = edi.player:get_money(player, item_id)\n    LOGI(\"isc player test: \"..before_money)\n    local count = 1000\n    edi.player:add_money(player, item_id, count)\n    local after_money = edi.player:get_money(player, item_id)\n    LOGI(\"isc player test: \".. after_money)\nend"
#         },
#         {
#             "description": "扣除货币",
#             "function_name": "sub_money",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "item_id",
#                     "type": "number",
#                     "comment": "货币配置id"
#                 },
#                 {
#                     "name": "count",
#                     "type": "number",
#                     "comment": "货币数量"
#                 }
#             ],
#             "return": {
#                 "type": "boolean",
#                 "comment": "是否扣除成功"
#             },
#             "example": "function isc_test_player:sub_money()\n    local player = module.player\n    local item_id = 1\n    local before_money = edi.player:get_money(player, item_id)\n    LOGI(\"isc player test: \"..before_money)\n    local count = 1000\n    edi.player:add_money(player, item_id, count)\n    local sub_count = 50\n    edi.player:sub_money(player, item_id, sub_count)\n    local after_money = edi.player:get_money(player, item_id)\n    LOGI(\"isc player test: \".. after_money)\nend"
#         },
#         {
#             "description": "设置指定地点复活",
#             "function_name": "relive_assign",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "pos",
#                     "type": "pos_info",
#                     "comment": "坐标"
#                 },
#                 {
#                     "name": "scene_id",
#                     "type": "number",
#                     "comment": "场景配置id"
#                 }
#             ],
#             "return": {
#                 "type": "boolean",
#                 "comment": "是否成功"
#             },
#             "example": "function isc_test_player:relive_assign()\n    local player = module.player\n    local obj = module.player:getOwner()\n    local scene = edi.object:get_scene(obj)\n    local pos = edi.scene:get_born_pos(scene)\n    LOGI(\"isc player test: \".. pos.x .. pos.y)\n    local scene_id = edi.scene:get_id(scene)\n    LOGI(\"isc player test: \".. scene_id)\n    local bRet = edi.player:relive_assign(player, pos, scene_id)\n    RET_BOOL(bRet,\"isc_test_player:assign_relive\")\nend"
#         },
#         {
#             "description": "原地复活",
#             "function_name": "relive_origin",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "return": {
#                 "type": "boolean",
#                 "comment": "是否成功"
#             },
#             "example": "function isc_test_player:relive_origin()\n    local player = module.player\n    local bRet = edi.player:relive_origin(player)\n    RET_BOOL(bRet, \"isc_test_player:origin_relive\")\nend"
#         },
#         {
#             "description": "设置玩家等级",
#             "function_name": "set_level",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "level",
#                     "type": "number",
#                     "comment": "等级"
#                 }
#             ],
#             "example": "function isc_test_player:set_level()\n    local player = module.player\n    local level = 50\n    edi.player:set_level(player, level)\n    local curr_level = edi.player:get_level(player)\n    LOGI(\"isc player test:\".. curr_level)\nend"
#         },
#         {
#             "description": "设置玩家转生等级",
#             "function_name": "set_rlevel",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "rlevel",
#                     "type": "number",
#                     "comment": "转生等级"
#                 }
#             ],
#             "example": "function isc_test_player:set_rlevel()\n    local player = module.player\n    local rlevel = 50\n    edi.player:set_rlevel(player, rlevel)\n    local curr_rlevel = edi.player:get_rlevel(player)\n    LOGI(\"isc player test:\".. curr_rlevel)\nend"
#         },
#         {
#             "description": "设置玩家攻击目标",
#             "function_name": "set_attack_target",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "object_id",
#                     "type": "string",
#                     "comment": "攻击目标uuid"
#                 }
#             ],
#             "example": "function isc_test_player:set_attack_target()\n\n    local scene_bit_player = 1\n    local scene_bit_monster = 1 << 1\n\n    local player = module.player\n    local obj = module.player:getOwner()\n    local target = nil\n    local nearPlayers = edi.scene:get_eye_objects(obj, scene_bit_player | scene_bit_monster)\n    for _, object in pairs(nearPlayers) do\n        if edi.object:get_uuid(obj) ~= edi.object:get_uuid(object) then\n            target = object\n            break\n        end\n    end\n\n    local object_id = edi.object:get_uuid(target)\n    edi.player:set_attack_target(player, tostring(object_id))\n    LOGI(\"isc player test: \" .. object_id .. \" name: \" .. edi.object:get_name(target))\nend"
#         },
#         {
#             "description": "获得指定属性值",
#             "function_name": "get_attr",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "attr_id",
#                     "type": "number",
#                     "comment": "属性id(attribute.xlsx表,对应attrDef.lua的AttrDef枚举, attr_id需1000以内)"
#                 }
#             ],
#             "return": {
#                 "type": "number",
#                 "comment": "属性值"
#             },
#             "example": "function isc_test_player:get_attr()\n    local player = module.player\n    local attr_id = AttrDef.EN_ATTR_1-- 当前生命\n    local val = edi.player:get_attr(player, attr_id)\n    LOGI(\"isc player test:\".. val)\nend"
#         },
#         {
#             "description": "设置属性值",
#             "function_name": "set_attr",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "attr_id",
#                     "type": "number",
#                     "comment": "属性id(attribute.xlsx表,对应attrDef.lua的AttrDef枚举, attr_id需1000以内)"
#                 },
#                 {
#                     "name": "val",
#                     "type": "number",
#                     "comment": "属性值"
#                 }
#             ],
#             "return": {
#                 "type": "boolean",
#                 "comment": "是否设置成功"
#             },
#             "example": "function isc_test_player:set_attr()\n    local player = module.player\n    local attr_id = AttrDef.EN_ATTR_1-- 当前生命 非累加属性id\n    local attr_val = 50\n    local before_val = edi.player:get_attr(player, attr_id)\n    LOGI(\"isc player test: before_val = \".. before_val)\n    edi.player:set_attr(player, attr_id, attr_val)\n    local after_val = edi.player:get_attr(player, attr_id)\n    LOGI(\"isc player test: after_val = \".. after_val)\n\n    print(\"set_attr cut2============================================================\")\n\n    local attr_id2 = AttrDef.EN_ATTR_21-- 暴击 累加属性id\n    local attr_val2 = 99\n    local before_val2 = edi.player:get_attr(player, attr_id2)\n    LOGI(\"isc player test: before_val2 = \".. before_val2)\n    edi.player:set_attr(player, attr_id2, attr_val2)\n    local after_val2 = edi.player:get_attr(player, attr_id2)\n    LOGI(\"isc player test: after_val2 = \".. after_val2)\n\n    print(\"set_attr cut3============================================================\")\n\n    local attr_id3 = 3000-- 自定义属性id\n    local attr_val3 = 1000\n    local before_val3 = edi.player:get_attr(player, attr_id3)\n    LOGI(\"isc player test: before_val3 = \".. before_val3)\n    edi.player:set_attr(player, attr_id3, attr_val3)\n    local after_val3 = edi.player:get_attr(player, attr_id3)\n    LOGI(\"isc player test: after_val3 = \".. after_val3)\n\n    print(\"set_attr accumulate============================================================\")\n\n    local attr_id4 = AttrDef.EN_ATTR_1-- 当前生命 非累加属性id\n    local attr_val4 = 100\n    local before_val4 = edi.player:get_attr(player, attr_id4)\n    LOGI(\"isc player test: before_val4 = \".. before_val4)\n    edi.player:change_attr(player, attr_id4, attr_val4)\n    local after_val4 = edi.player:get_attr(player, attr_id4)\n    LOGI(\"isc player test: after_val4 = \".. after_val4)\n\n    print(\"set_attr accumulate2============================================================\")\n\n    local attr_id5 = AttrDef.EN_ATTR_21-- 暴击 累加属性id\n    local attr_val5 = 200\n    local before_val5 = edi.player:get_attr(player, attr_id5)\n    LOGI(\"isc player test: before_val5 = \".. before_val5)\n    edi.player:change_attr(player, attr_id5, attr_val5)\n    local after_val5 = edi.player:get_attr(player, attr_id5)\n    LOGI(\"isc player test: after_val5 = \".. after_val5)\nend"
#         },
#         {
#             "description": "修改属性值",
#             "function_name": "change_attr",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "attr_id",
#                     "type": "number",
#                     "comment": "属性id(attribute.xlsx表,对应attrDef.lua的AttrDef枚举, attr_id需1000以内)"
#                 },
#                 {
#                     "name": "val",
#                     "type": "number",
#                     "comment": "属性值"
#                 }
#             ],
#             "return": {
#                 "type": "boolean",
#                 "comment": "是否修改成功"
#             },
#             "example": "function isc_test_player:change_attr()\n    local player = module.player\n    local attr_id = AttrDef.EN_ATTR_1-- 当前生命\n    local attr_val = 50\n    local before_val = edi.player:get_attr(player, attr_id)\n    LOGI(\"isc player test:\".. before_val)\n    edi.player:change_attr(player, attr_id, attr_val)\n    local after_val = edi.player:get_attr(player, attr_id)\n    LOGI(\"isc player test:\".. after_val)\nend"
#         },
#         {
#             "description": "获取指定模块的键值对Key对应的值(int2int)",
#             "function_name": "get_int_kv",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "mod",
#                     "type": "KVModeDef",
#                     "comment": "自定义模块ID(constDef.lua的KVModeDef枚举，引擎提供枚举值100以内, 客户自定义模块枚举值需>100，若使用引擎提供mod枚举,key需要>3000)"
#                 },
#                 {
#                     "name": "key",
#                     "type": "number",
#                     "comment": "自定义Key"
#                 }
#             ],
#             "return": {
#                 "type": "number",
#                 "comment": "自定义Key对应值"
#             },
#             "example": "function isc_test_player:get_int_kv()\n    local player = module.player\n    local curr_exp = edi.player:get_int_kv(player, ConstDef.KVModeDef.eDEFAULT, OtherDef.EN_OTHER_2)\n    LOGI(\"isc player test:\".. curr_exp)\nend"
#         },
#         {
#             "description": "设置指定模块的键值对Key对应值(int2int)",
#             "function_name": "set_int_kv",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "mod",
#                     "type": "KVModeDef",
#                     "comment": "自定义模块ID(constDef.lua的KVModeDef枚举，引擎提供枚举值100以内, 客户自定义模块枚举值需>100，若使用引擎提供mod枚举,key需要>3000)"
#                 },
#                 {
#                     "name": "key",
#                     "type": "number",
#                     "comment": "自定义Key"
#                 },
#                 {
#                     "name": "val",
#                     "type": "number",
#                     "comment": "自定义Key对应值"
#                 }
#             ],
#             "example": "function isc_test_player:set_int_kv()\n    local player = module.player\n    local val = 99\n    local before_exp = edi.player:get_int_kv(player, ConstDef.KVModeDef.eDEFAULT, OtherDef.EN_OTHER_2)\n    LOGI(\"isc player test:\".. before_exp)\n    edi.player:set_int_kv(player, ConstDef.KVModeDef.eDEFAULT, OtherDef.EN_OTHER_2, val)\n    local after_exp = edi.player:get_int_kv(player, ConstDef.KVModeDef.eDEFAULT, OtherDef.EN_OTHER_2)\n    LOGI(\"isc player test:\".. after_exp)\nend"
#         },
#         {
#             "description": "获取指定模块的键值对Key对应的值(str2str)",
#             "function_name": "get_str_kv",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "mod",
#                     "type": "KVModeDef",
#                     "comment": "自定义模块ID"
#                 },
#                 {
#                     "name": "key",
#                     "type": "string",
#                     "comment": "自定义Key"
#                 }
#             ],
#             "return": {
#                 "type": "string",
#                 "comment": "自定义Key对应值"
#             },
#             "example": "function isc_test_player:get_str_kv()\n    local player = module.player\n    local kvDef = ConstDef.KVModeDef.eGrowUp\n    local key = \"isc_test_player\"\n    local val = \"success\"\n    edi.player:set_str_kv(player, kvDef, key, val)\n    local curval = edi.player:get_str_kv(player, kvDef, key)\n    LOGI(\"isc player test:\".. curval)\nend"
#         },
#         {
#             "description": "设置指定模块的键值对Key对应值(str2str)",
#             "function_name": "set_str_kv",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "mod",
#                     "type": "KVModeDef",
#                     "comment": "自定义模块ID"
#                 },
#                 {
#                     "name": "key",
#                     "type": "string",
#                     "comment": "自定义Key"
#                 },
#                 {
#                     "name": "val",
#                     "type": "string",
#                     "comment": "自定义Key对应值"
#                 }
#             ],
#             "example": "function isc_test_player:set_str_kv()\n    local player = module.player\n    local kvDef = ConstDef.KVModeDef.eGrowUp\n    local key = \"isc_test_player\"\n    local val = \"success\"\n    edi.player:set_str_kv(player, kvDef, key, val)\n    local curval = edi.player:get_str_kv(player, kvDef, key)\n    LOGI(\"isc player test:\".. curval)\nend"
#         },
#         {
#             "description": "获取指定模块的键值对Key对应的值(str2int)",
#             "function_name": "get_growth_kv",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "mod",
#                     "type": "KVModeDef",
#                     "comment": "自定义模块ID(constDef.lua的KVModeDef枚举)"
#                 },
#                 {
#                     "name": "key",
#                     "type": "string",
#                     "comment": "自定义Key"
#                 }
#             ],
#             "return": {
#                 "type": "number",
#                 "comment": "自定义Key对应值"
#             },
#             "example": null
#         },
#         {
#             "description": "设置指定模块的键值对Key对应值(str2int)",
#             "function_name": "set_growth_kv",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "mod",
#                     "type": "KVModeDef",
#                     "comment": "自定义模块ID(constDef.lua的KVModeDef枚举)"
#                 },
#                 {
#                     "name": "key",
#                     "type": "string",
#                     "comment": "自定义Key"
#                 },
#                 {
#                     "name": "val",
#                     "type": "number",
#                     "comment": "自定义Key对应值"
#                 }
#             ],
#             "example": null
#         },
#         {
#             "description": "设置红点",
#             "function_name": "set_red_point",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "red_point",
#                     "type": "number",
#                     "comment": "红点id"
#                 },
#                 {
#                     "name": "notify",
#                     "type": "boolean",
#                     "comment": "是否通知客户端"
#                 }
#             ],
#             "example": "function isc_test_player:set_red_point()\n    local player = module.player\n    local red_point = 1\n    local notify = true\n    edi.player:set_red_point(player, red_point, notify)\n    local bRet = edi.player:get_red_point(player, red_point)\n    RET_BOOL(bRet, \"isc_test_player:get_red_point\")\nend"
#         },
#         {
#             "description": "获得红点",
#             "function_name": "get_red_point",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "red_point",
#                     "type": "number",
#                     "comment": "红点id"
#                 }
#             ],
#             "return": {
#                 "type": "boolean",
#                 "comment": "是否存在该红点"
#             },
#             "example": "function isc_test_player:get_red_point()\n    local player = module.player\n    local red_point = 1\n    local notify = true\n    edi.player:set_red_point(player, red_point, notify)\n    local bRet = edi.player:get_red_point(player, red_point)\n    RET_BOOL(bRet, \"isc_test_player:get_red_point\")\nend"
#         },
#         {
#             "description": "玩家数据打包入库",
#             "function_name": "save_db",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "example": "function isc_test_player:save_db()\n    local player = module.player\n    edi.player:save_db(player)\nend"
#         },
#         {
#             "description": "player添加定时器",
#             "function_name": "add_timer",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "index_key",
#                     "type": "string",
#                     "comment": "标记"
#                 },
#                 {
#                     "name": "tick",
#                     "type": "number",
#                     "comment": "间隔时间(毫秒)"
#                 },
#                 {
#                     "name": "count",
#                     "type": "number",
#                     "comment": "重复次数"
#                 },
#                 {
#                     "name": "callback_func",
#                     "type": "function",
#                     "comment": "回调函数"
#                 },
#                 {
#                     "name": "callback_data",
#                     "type": "string",
#                     "comment": "回调数据"
#                 }
#             ],
#             "return": {
#                 "type": "boolean",
#                 "comment": "是否成功"
#             },
#             "example": "function isc_test_player:add_timer()\n\n    local _callback = function(player_uid, callback_params)\n        print(\"isc_test_player:callback================================== \", player_uid, callback_params)\n    end\n\n    local player = module.player\n    local index_key = \"player_timer\"\n    local tick = 200\n    local count = 1\n    local params = \"6\"\n\n    local bRet = edi.player:add_timer(player, index_key, tick, count, _callback, params)\n    RET_BOOL(bRet, \"isc_test_player:add_timer\")\nend"
#         },
#         {
#             "description": "删除指定定时器",
#             "function_name": "del_timer",
#             "args": [
#                 {
#                     "name": "index_key",
#                     "type": "string",
#                     "comment": "标记"
#                 }
#             ],
#             "example": "function isc_test_player:del_timer()\n    local player = module.player\n    local index_key = \"player_timer\"\n    edi.player:del_timer(index_key)\nend"
#         },
#         {
#             "description": "判断是否有指定定时器",
#             "function_name": "has_timer",
#             "args": [
#                 {
#                     "name": "index_key",
#                     "type": "string",
#                     "comment": "标记"
#                 }
#             ],
#             "return": {
#                 "type": "boolean",
#                 "comment": "是否成功"
#             },
#             "example": "function isc_test_player:has_timer()\n    local player = module.player\n    local index_key = \"player_timer\"\n    local bRet = edi.player:has_timer(index_key)\n    RET_BOOL(bRet, \"isc_test_player:has_timer\")\nend"
#         },
#         {
#             "description": "通知客户端属性变化",
#             "function_name": "send_attr_change",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 }
#             ],
#             "example": "function isc_test_player:send_attr_change()\n    local player = module.player\n    edi.player:send_attr_change(player)\nend"
#         },
#         {
#             "description": "充值接口",
#             "function_name": "recharge",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "product",
#                     "type": "string",
#                     "comment": "充值商品"
#                 },
#                 {
#                     "name": "custom_data",
#                     "type": "string",
#                     "comment": "用户自定义透传数据"
#                 },
#                 {
#                     "name": "is_real",
#                     "type": "integer",
#                     "comment": ""
#                 },
#                 {
#                     "name": "resource",
#                     "type": "string",
#                     "comment": "原因"
#                 }
#             ],
#             "example": "function isc_test_player:recharge()\n    local player = module.player\n    edi.player:recharge(player, \"com.cq.1\", \"1|2|4\", 1, \"test reason\")\n    edi.player:recharge(player, \"com.cq.1\", \"1|2|4\", 0, \"test reason\")\nend"
#         },
#         {
#             "description": "设置显示信息",
#             "function_name": "set_show",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "show",
#                     "type": "player_show_info",
#                     "comment": "显示信息对象(player_show_info结构)"
#                 }
#             ],
#             "return": {
#                 "type": "boolean",
#                 "comment": "是否成功"
#             },
#             "example": "function isc_test_player:set_show()\n    local player = module.player\n    local ret = edi.player:set_show(player, {id = 1, show_type=1, ctx=\"context\"})\n    print(\"result = \", ret)\nend"
#         },
#         {
#             "description": "获取显示信息",
#             "function_name": "get_show",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "id",
#                     "type": "number",
#                     "comment": "显示信息id"
#                 }
#             ],
#             "return": {
#                 "type": "player_show_info",
#                 "comment": "显示信息对象("
#             },
#             "example": "function isc_test_player:get_show()\n    local player = module.player\n    local ret = edi.player:get_show(player, 1)\n    print(\"result = \", ret)\nend"
#         },
#         {
#             "description": "设置外观显示",
#             "function_name": "set_outlook",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "type",
#                     "type": "eOutLookType",
#                     "comment": "外观显示类型"
#                 },
#                 {
#                     "name": "val",
#                     "type": "number",
#                     "comment": "外观显示类型对应值"
#                 }
#             ],
#             "return": {
#                 "type": "boolean",
#                 "comment": "是否成功"
#             },
#             "example": "function isc_test_player:set_outlook()\n    local player = module.player\n    local ret = edi.player:set_outlook(player, 1, 1)\n    print(\"result = \", ret)\nend"
#         },
#         {
#             "description": "获取外观显示",
#             "function_name": "get_outlook",
#             "args": [
#                 {
#                     "name": "player",
#                     "type": "userdata",
#                     "comment": "玩家对象"
#                 },
#                 {
#                     "name": "type",
#                     "type": "eOutLookType",
#                     "comment": "外观显示类型"
#                 }
#             ],
#             "return": {
#                 "type": "number",
#                 "comment": "外观显示类型对应值"
#             },
#             "example": "function isc_test_player:get_outlook()\n    local player = module.player\n    local ret = edi.player:get_outlook(player, 1)\n    print(\"result = \", ret)\nend"
#         }
#     ]
# }
